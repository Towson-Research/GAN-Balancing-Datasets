# %%
from gan import GAN
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/tensorflow/python/pywrap_tensorflow.py in <module>
#      57
# ---> 58   from tensorflow.python.pywrap_tensorflow_internal import *
#      59   from tensorflow.python.pywrap_tensorflow_internal import __version__
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in <module>
#      27             return _mod
# ---> 28     _pywrap_tensorflow_internal = swig_import_helper()
#      29     del swig_import_helper
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/pywrap_tensorflow_internal.py in swig_import_helper()
#      23             try:
# ---> 24                 _mod = imp.load_module('_pywrap_tensorflow_internal', fp, pathname, description)
#      25             finally:
#
# ...

# %%
args = {
    'attack_type': "neptune",    # optional v
    'max_epochs': 7000,
    'batch_size': 255,
    'sample_size': 500,
    'optimizer_learning_rate': 0.001
}
gan = GAN(**args)
gan.train()

# %%
import sys
print(sys.path)
# Out:
# ['/usr/lib/python36.zip', '/usr/lib/python3.6', '/usr/lib/python3.6/lib-dynload', '', '/home/ldeng/.local/lib/python3.6/site-packages', '/usr/local/lib/python3.6/dist-packages', '/usr/lib/python3/dist-packages', '/home/ldeng/.local/lib/python3.6/site-packages/IPython/extensions', '/home/ldeng/.ipython']
