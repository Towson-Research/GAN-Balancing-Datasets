# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import math
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Dropout, BatchNormalization
from keras.layers.advanced_activations import LeakyReLU
from keras.optimizers import Adam
from sklearn.preprocessing import LabelEncoder
# Out:
# Using TensorFlow backend.

# %%
def build_discriminator(layer1, layer2, layer3):
    model = Sequential()
    model.add(Dense(layer1, input_dim=41)) #discriminator takes 41 values from our dataset
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.3))
    model.add(Dense(layer2))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.3))
    model.add(Dense(layer3))
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dropout(0.3))
    model.add(Dense(1, activation='sigmoid')) #outputs 0 to 1, 1 being real and 0 being fake

    attack = Input(shape=(41,))
    validity = model(attack)

    return Model(attack, validity)

# %%
def build_generator(layer1, layer2, layer3):
    model = Sequential()
    model.add(Dense(layer1, input_dim=41))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(layer2))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(layer3))
    model.add(BatchNormalization())
    model.add(LeakyReLU(alpha=0.2))
    model.add(Dense(41, activation='relu'))

    noise = Input(shape=(41,))
    attack = model(noise)
    return Model(noise, attack)

# %%
def GAN_model(layer1, layer2, layer3):
    optimizer = Adam(0.001)
    
    #build generator and discriminator (mirrored)
    generator = build_generator(layer1, layer2, layer3)
    
    discriminator = build_discriminator(layer3, layer2, layer1)
    discriminator.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    
    #input and output of our combined model
    z = Input(shape=(41,))
    attack = generator(z)
    validity = discriminator(attack)
    
    #build combined model from generator and discriminator
    combined = Model(z, validity)
    combined.compile(loss='binary_crossentropy', optimizer=optimizer)
    return combined, discriminator, generator

# %%
def train_loop(combined, discriminator, generator, epochs):
    epochs = epochs
    batch_size = 4999
    dataframe = pd.read_csv('../../../../CSV/kdd_neptune_only_5000.csv').sample(batch_size)
    
    #apply "le.fit_transform" to every column (usually only works on 1 column)
    le = LabelEncoder()
    dataframe_encoded = dataframe.apply(le.fit_transform)
    dataset = dataframe_encoded.values
    
    #labels for data. 1 for valid attacks, 0 for fake (generated) attacks
    valid = np.ones((batch_size, 1))
    fake = np.zeros((batch_size, 1))
    
    #Set X as our input data and Y as our label
    X_train = dataset[:, 0:41].astype(float)
    Y_train = dataset[:, 41]
    
    #break condition for training (when diverging)
    loss_increase_count = 0
    prev_g_loss = 0
    
    #generating a np array of numbers 0..batch_size-1
    idx = np.arange(batch_size)
    
    for epoch in range(epochs):
        #selecting batch_size random attacks from our training data
        #idx = np.random.randint(0, X_train.shape[0], batch_size)
        attacks = X_train[idx]
        
        #generate a matrix of noise vectors
        noise = np.random.normal(0, 1, (batch_size, 41))
        
        #create an array of generated attacks
        gen_attacks = generator.predict(noise)
        
        #loss functions, based on what metrics we specify at model compile time
        d_loss_real = discriminator.train_on_batch(attacks, valid)
        d_loss_fake = discriminator.train_on_batch(gen_attacks, fake)
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
        
        #generator loss function
        g_loss = combined.train_on_batch(noise, valid)
        
        if epoch % 50 == 0:
            print("%d [D loss: %f, acc.: %.2f%%] [G loss: %f] [Loss change: %.3f, Loss increases: %.0f]" % 
                  (epoch, d_loss[0], 100 * d_loss[1], g_loss, g_loss - prev_g_loss, loss_increase_count))
        
            #saving results to txt to track them as the gan is training
            f = open("GANresultsNeptune.txt", "a")
            np.savetxt("GANresultsNeptune.txt", gen_attacks, fmt="%d")
            f.close()
        
            results = np.loadtxt("GANresultsNeptune.txt")
            y_pred = estimator.predict(results)
        
            right = (y_pred == 1).sum()
            wrong = len(y_pred)-(y_pred == 1).sum()
            accuracy = (right/float(right+wrong))
            print("Number of right predictions: %d" % right)
            print("Number of wrong predictions: %d" % wrong)
            print("Accuracy: %.4f " % accuracy)

# %%
#Initialize Random Number Generator
#fix random seed for reproducibility
seed = 7
np.random.seed(seed)

#load dataset
dataframe = pd.read_csv("../../../../CSV/normalAndNeptune.csv")

#samples n random data points
dataframe = dataframe.sample(n=1000000)
#LabelEncoder, turns all our categorical data into integers
le = LabelEncoder()

#apply "le.fit_transform" to every column (usually only works on 1 column)
dataframe_encoded = dataframe.apply(le.fit_transform)
attack_labels = le.classes_
indices_of_neptune = np.where(attack_labels == 'neptune.')
neptune_index = indices_of_neptune[0]
dataset = dataframe_encoded.values

#Set X as our input data and Y as our label
X = dataset[:,0:41].astype(float)
Y = dataset[:,41]

# %%
#Get validation data
validationToTrainRatio = 0.05
validationSize = int(validationToTrainRatio * len(X))
validationData = X[:validationSize]
validationLabels = Y[:validationSize]
X = X[validationSize:]
Y = Y[validationSize:]

#Get test data
testToTrainRatio = 0.05
testSize = int(testToTrainRatio * len(X))
testData = X[:testSize]
testLabels = Y[:testSize]
X = X[testSize:]
Y = Y[testSize:]

# %%
def baseline_model(layers, units, dropout_rate, input_shape, num_classes):
    model = Sequential()
    model.add(Dropout(rate=dropout_rate, input_shape=input_shape))
    for _ in range(layers-1):
        model.add(Dense(units=units, activation=tf.nn.relu))
        model.add(Dropout(rate=dropout_rate))

    model.add(Dense(units=num_classes, activation=tf.nn.sigmoid))
    model.compile(optimizer=tf.train.AdamOptimizer(learning_rate=0.001),
              loss='binary_crossentropy',
              metrics=['accuracy'])
    return model

# %%
estimator = baseline_model(layers=2, units=32, dropout_rate=0.5, input_shape=X.shape[1:], num_classes=1)

callbacks = [tf.keras.callbacks.EarlyStopping(
        monitor='val_loss', patience=2)]

history = estimator.fit(X,
                    Y,
                    epochs=5,
                    batch_size=1024,
                    callbacks=callbacks,
                    validation_data=(validationData, validationLabels),
                    verbose=2)
# Out:
# Train on 902500 samples, validate on 50000 samples
# Epoch 1/5
#  - 2s - loss: 0.5924 - acc: 0.9302 - val_loss: 0.0039 - val_acc: 0.9999
# Epoch 2/5
#  - 2s - loss: 0.0470 - acc: 0.9861 - val_loss: 0.0065 - val_acc: 0.9998
# Epoch 3/5
#  - 2s - loss: 0.0325 - acc: 0.9898 - val_loss: 0.0034 - val_acc: 0.9999
# Epoch 4/5
#  - 3s - loss: 0.0277 - acc: 0.9909 - val_loss: 0.0014 - val_acc: 0.9999
# Epoch 5/5
#  - 2s - loss: 0.0246 - acc: 0.9917 - val_loss: 0.0011 - val_acc: 0.9999

# %%
#Evalueating model on the testset
#[loss, accuracy]
print(estimator.evaluate(testData, testLabels))
# Out:
# 47500/47500 [==============================] - 0s 5us/step
# [0.001588432508278148, 0.9998947368421053]

# %%
#creating GAN model
combined, discriminator, generator = GAN_model(8, 16, 32)

# %%
#training GAN model
train_loop(combined, discriminator, generator, 3000)
# Out:
# 0 [D loss: 2.912833, acc.: 47.12%] [G loss: 0.772308] [Loss change: 0.772, Loss increases: 0]
# Number of right predictions: 0
# Number of wrong predictions: 4999
# Accuracy: 0.0000
# 50 [D loss: 1.061426, acc.: 50.19%] [G loss: 0.200673] [Loss change: 0.201, Loss increases: 0]
# Number of right predictions: 10
# Number of wrong predictions: 4989
# Accuracy: 0.0020
# 100 [D loss: 1.278765, acc.: 50.32%] [G loss: 0.134233] [Loss change: 0.134, Loss increases: 0]
# Number of right predictions: 1
# Number of wrong predictions: 4998
# Accuracy: 0.0002
# 150 [D loss: 1.432770, acc.: 50.40%] [G loss: 0.116660] [Loss change: 0.117, Loss increases: 0]
# Number of right predictions: 0
# Number of wrong predictions: 4999
# Accuracy: 0.0000
# 200 [D loss: 1.554451, acc.: 50.72%] [G loss: 0.108443] [Loss change: 0.108, Loss increases: 0]
# Number of right predictions: 0
# Number of wrong predictions: 4999
# Accuracy: 0.0000
# 250 [D loss: 1.593465, acc.: 50.68%] [G loss: 0.112816] [Loss change: 0.113, Loss increases: 0]
# Number of right predictions: 0
# Number of wrong predictions: 4999
# Accuracy: 0.0000
# 300 [D loss: 1.596891, acc.: 50.91%] [G loss: 0.108561] [Loss change: 0.109, Loss increases: 0]
# Number of right predictions: 0
# Number of wrong predictions: 4999
# Accuracy: 0.0000
# 350 [D loss: 1.626827, acc.: 50.80%] [G loss: 0.119710] [Loss change: 0.120, Loss increases: 0]
# Number of right predictions: 0
# Number of wrong predictions: 4999
# Accuracy: 0.0000
# 400 [D loss: 1.660538, acc.: 50.65%] [G loss: 0.116470] [Loss change: 0.116, Loss increases: 0]
# Number of right predictions: 0
# Number of wrong predictions: 4999
# Accuracy: 0.0000
# 450 [D loss: 1.681563, acc.: 50.79%] [G loss: 0.120349] [Loss change: 0.120, Loss increases: 0]
# Number of right predictions: 0
# Number of wrong predictions: 4999
# Accuracy: 0.0000
# 500 [D loss: 1.750111, acc.: 50.83%] [G loss: 0.134117] [Loss change: 0.134, Loss increases: 0]
# Number of right predictions: 0
# Number of wrong predictions: 4999
# Accuracy: 0.0000
# 550 [D loss: 1.771127, acc.: 50.94%] [G loss: 0.138033] [Loss change: 0.138, Loss increases: 0]
# Number of right predictions: 0
# Number of wrong predictions: 4999
# Accuracy: 0.0000
# 600 [D loss: 1.793170, acc.: 50.62%] [G loss: 0.133121] [Loss change: 0.133, Loss increases: 0]
# Number of right predictions: 0
# Number of wrong predictions: 4999
# Accuracy: 0.0000
# 650 [D loss: 1.804130, acc.: 50.64%] [G loss: 0.137211] [Loss change: 0.137, Loss increases: 0]
# Number of right predictions: 0
# Number of wrong predictions: 4999
# Accuracy: 0.0000
# 700 [D loss: 1.781673, acc.: 51.08%] [G loss: 0.146149] [Loss change: 0.146, Loss increases: 0]
# Number of right predictions: 0
# Number of wrong predictions: 4999
# Accuracy: 0.0000
# 750 [D loss: 1.807963, acc.: 51.16%] [G loss: 0.146320] [Loss change: 0.146, Loss increases: 0]
# Number of right predictions: 0
# Number of wrong predictions: 4999
# Accuracy: 0.0000
# 800 [D loss: 1.742955, acc.: 51.31%] [G loss: 0.146882] [Loss change: 0.147, Loss increases: 0]
# Number of right predictions: 0
# Number of wrong predictions: 4999
# Accuracy: 0.0000
# 850 [D loss: 1.756713, acc.: 50.93%] [G loss: 0.164296] [Loss change: 0.164, Loss increases: 0]
# Number of right predictions: 0
# Number of wrong predictions: 4999
# Accuracy: 0.0000
# 900 [D loss: 1.763277, acc.: 51.32%] [G loss: 0.163447] [Loss change: 0.163, Loss increases: 0]
# Number of right predictions: 0
# Number of wrong predictions: 4999
# Accuracy: 0.0000
# 950 [D loss: 1.737747, acc.: 51.15%] [G loss: 0.156522] [Loss change: 0.157, Loss increases: 0]
# Number of right predictions: 2358
# Number of wrong predictions: 2641
# Accuracy: 0.4717
# 1000 [D loss: 1.695738, acc.: 51.06%] [G loss: 0.170075] [Loss change: 0.170, Loss increases: 0]
# Number of right predictions: 3259
# Number of wrong predictions: 1740
# Accuracy: 0.6519
# 1050 [D loss: 1.728899, acc.: 50.88%] [G loss: 0.172045] [Loss change: 0.172, Loss increases: 0]
# Number of right predictions: 4999
# Number of wrong predictions: 0
# Accuracy: 1.0000
# 1100 [D loss: 1.727196, acc.: 50.74%] [G loss: 0.169925] [Loss change: 0.170, Loss increases: 0]
# Number of right predictions: 4999
# Number of wrong predictions: 0
# Accuracy: 1.0000
# 1150 [D loss: 1.690099, acc.: 50.44%] [G loss: 0.173718] [Loss change: 0.174, Loss increases: 0]
# Number of right predictions: 4999
# Number of wrong predictions: 0
# Accuracy: 1.0000
# 1200 [D loss: 1.691375, acc.: 50.83%] [G loss: 0.175915] [Loss change: 0.176, Loss increases: 0]
# Number of right predictions: 4999
# Number of wrong predictions: 0
# Accuracy: 1.0000
# 1250 [D loss: 1.632031, acc.: 50.69%] [G loss: 0.173032] [Loss change: 0.173, Loss increases: 0]
# Number of right predictions: 4999
# Number of wrong predictions: 0
# Accuracy: 1.0000
# 1300 [D loss: 1.641967, acc.: 50.59%] [G loss: 0.176831] [Loss change: 0.177, Loss increases: 0]
# Number of right predictions: 4999
# Number of wrong predictions: 0
# Accuracy: 1.0000
# 1350 [D loss: 1.660395, acc.: 50.52%] [G loss: 0.175954] [Loss change: 0.176, Loss increases: 0]
# Number of right predictions: 4999
# Number of wrong predictions: 0
# Accuracy: 1.0000
# 1400 [D loss: 1.636553, acc.: 50.33%] [G loss: 0.192879] [Loss change: 0.193, Loss increases: 0]
# Number of right predictions: 4999
# Number of wrong predictions: 0
# Accuracy: 1.0000
# 1450 [D loss: 1.644946, acc.: 50.51%] [G loss: 0.200002] [Loss change: 0.200, Loss increases: 0]
# Number of right predictions: 4999
# Number of wrong predictions: 0
# Accuracy: 1.0000
# 1500 [D loss: 1.622953, acc.: 50.36%] [G loss: 0.205127] [Loss change: 0.205, Loss increases: 0]
# Number of right predictions: 4999
# Number of wrong predictions: 0
# Accuracy: 1.0000
# 1550 [D loss: 1.619642, acc.: 50.63%] [G loss: 0.196875] [Loss change: 0.197, Loss increases: 0]
# Number of right predictions: 4999
# Number of wrong predictions: 0
# Accuracy: 1.0000
# 1600 [D loss: 1.575899, acc.: 50.54%] [G loss: 0.192567] [Loss change: 0.193, Loss increases: 0]
# Number of right predictions: 4999
# Number of wrong predictions: 0
# Accuracy: 1.0000
# 1650 [D loss: 1.557375, acc.: 50.64%] [G loss: 0.198638] [Loss change: 0.199, Loss increases: 0]
# Number of right predictions: 4999
# Number of wrong predictions: 0
# Accuracy: 1.0000
# 1700 [D loss: 1.475443, acc.: 50.91%] [G loss: 0.196323] [Loss change: 0.196, Loss increases: 0]
# Number of right predictions: 4999
# Number of wrong predictions: 0
# Accuracy: 1.0000
# 1750 [D loss: 1.459970, acc.: 50.76%] [G loss: 0.196332] [Loss change: 0.196, Loss increases: 0]
# Number of right predictions: 4999
# Number of wrong predictions: 0
# Accuracy: 1.0000
# 1800 [D loss: 1.454976, acc.: 50.75%] [G loss: 0.198326] [Loss change: 0.198, Loss increases: 0]
# Number of right predictions: 4999
# Number of wrong predictions: 0
# Accuracy: 1.0000
# 1850 [D loss: 1.461491, acc.: 50.90%] [G loss: 0.202477] [Loss change: 0.202, Loss increases: 0]
# Number of right predictions: 4999
# Number of wrong predictions: 0
# Accuracy: 1.0000
# 1900 [D loss: 1.496491, acc.: 50.40%] [G loss: 0.219214] [Loss change: 0.219, Loss increases: 0]
# Number of right predictions: 4999
# Number of wrong predictions: 0
# Accuracy: 1.0000
# 1950 [D loss: 1.409975, acc.: 50.47%] [G loss: 0.191129] [Loss change: 0.191, Loss increases: 0]
# Number of right predictions: 4999
# Number of wrong predictions: 0
# Accuracy: 1.0000
# 2000 [D loss: 1.398799, acc.: 50.47%] [G loss: 0.183923] [Loss change: 0.184, Loss increases: 0]
# Number of right predictions: 4999
# Number of wrong predictions: 0
# Accuracy: 1.0000
# 2050 [D loss: 1.429127, acc.: 49.93%] [G loss: 0.207031] [Loss change: 0.207, Loss increases: 0]
# Number of right predictions: 4999
# Number of wrong predictions: 0
# Accuracy: 1.0000
# 2100 [D loss: 1.464055, acc.: 50.05%] [G loss: 0.204667] [Loss change: 0.205, Loss increases: 0]
# Number of right predictions: 4999
# Number of wrong predictions: 0
# Accuracy: 1.0000
# 2150 [D loss: 1.451671, acc.: 50.23%] [G loss: 0.217102] [Loss change: 0.217, Loss increases: 0]
# Number of right predictions: 4999
# Number of wrong predictions: 0
# Accuracy: 1.0000
# 2200 [D loss: 1.455325, acc.: 50.26%] [G loss: 0.216952] [Loss change: 0.217, Loss increases: 0]
# Number of right predictions: 4999
# Number of wrong predictions: 0
# Accuracy: 1.0000
# 2250 [D loss: 1.428807, acc.: 50.40%] [G loss: 0.217384] [Loss change: 0.217, Loss increases: 0]
# Number of right predictions: 4999
# Number of wrong predictions: 0
# Accuracy: 1.0000
# 2300 [D loss: 1.436085, acc.: 50.45%] [G loss: 0.228094] [Loss change: 0.228, Loss increases: 0]
# Number of right predictions: 4009
# Number of wrong predictions: 990
# Accuracy: 0.8020
# 2350 [D loss: 1.425448, acc.: 50.93%] [G loss: 0.239136] [Loss change: 0.239, Loss increases: 0]
# Number of right predictions: 3910
# Number of wrong predictions: 1089
# Accuracy: 0.7822
# 2400 [D loss: 1.411537, acc.: 50.60%] [G loss: 0.221286] [Loss change: 0.221, Loss increases: 0]
# Number of right predictions: 3823
# Number of wrong predictions: 1176
# Accuracy: 0.7648
# 2450 [D loss: 1.363901, acc.: 51.19%] [G loss: 0.229827] [Loss change: 0.230, Loss increases: 0]
# Number of right predictions: 3786
# Number of wrong predictions: 1213
# Accuracy: 0.7574
# 2500 [D loss: 1.376582, acc.: 51.15%] [G loss: 0.228105] [Loss change: 0.228, Loss increases: 0]
# Number of right predictions: 3819
# Number of wrong predictions: 1180
# Accuracy: 0.7640
# 2550 [D loss: 1.518611, acc.: 51.05%] [G loss: 0.256750] [Loss change: 0.257, Loss increases: 0]
# Number of right predictions: 3592
# Number of wrong predictions: 1407
# Accuracy: 0.7185
# 2600 [D loss: 1.426708, acc.: 50.88%] [G loss: 0.239245] [Loss change: 0.239, Loss increases: 0]
# Number of right predictions: 3682
# Number of wrong predictions: 1317
# Accuracy: 0.7365
# 2650 [D loss: 1.413067, acc.: 51.36%] [G loss: 0.246987] [Loss change: 0.247, Loss increases: 0]
# Number of right predictions: 3635
# Number of wrong predictions: 1364
# Accuracy: 0.7271
# 2700 [D loss: 1.330303, acc.: 51.37%] [G loss: 0.239091] [Loss change: 0.239, Loss increases: 0]
# Number of right predictions: 3483
# Number of wrong predictions: 1516
# Accuracy: 0.6967
# 2750 [D loss: 1.291667, acc.: 52.24%] [G loss: 0.243177] [Loss change: 0.243, Loss increases: 0]
# Number of right predictions: 2668
# Number of wrong predictions: 2331
# Accuracy: 0.5337
# 2800 [D loss: 1.310962, acc.: 52.55%] [G loss: 0.263119] [Loss change: 0.263, Loss increases: 0]
# Number of right predictions: 3091
# Number of wrong predictions: 1908
# Accuracy: 0.6183
# 2850 [D loss: 1.289502, acc.: 52.35%] [G loss: 0.263027] [Loss change: 0.263, Loss increases: 0]
# Number of right predictions: 1623
# Number of wrong predictions: 3376
# Accuracy: 0.3247
# 2900 [D loss: 1.268676, acc.: 52.91%] [G loss: 0.267462] [Loss change: 0.267, Loss increases: 0]
# Number of right predictions: 1943
# Number of wrong predictions: 3056
# Accuracy: 0.3887
# 2950 [D loss: 1.237024, acc.: 53.37%] [G loss: 0.254262] [Loss change: 0.254, Loss increases: 0]
# Number of right predictions: 1883
# Number of wrong predictions: 3116
# Accuracy: 0.3767
